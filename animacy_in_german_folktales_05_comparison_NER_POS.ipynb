# %% [markdown]
# # Animacy in German Folktales
#
# This notebook contains the reproducible code examples and analyses for the paper *"Animacy in German Folktales"* submitted in proceedings of CHR 2024: Computational Humanities Research Conference, 2024, Aarhus, Denmark.
#
# **Authors:** Julian Häußler, Janis von Keitz, Evelyn Gius
#
# **Institution:** *fortext lab, Technical University of Darmstadt, Germany*
#
# **Reference:** Häußler, J., von Keitz, J., Gius, E. (2024). *Animacy in German Folktales*. CHR 2024: Computational Humanities Research Conference, December 4 – 6, 2024, Aarhus, Denmark. https://ceur-ws.org/Vol-3834/paper90.pdf.
#
# **GitHub Repository:** https://github.com/forTEXT/Animacy_in_German_Folktales

# %% [markdown]
# ## Notebook 05: Comparison NER and POS

# %% [markdown]
# ### NER

# %%
# Import libraries

import json
import os
import pandas as pd

# %%
# Load data

input_folder = '../Data/annotations'

# %%
texts_as_dfs = []
lst_khm_ids = []

# %%
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)

    lst_khm_ids.append(int(filename.replace('_annotations.json', '')))

    with open(file_path, 'r', encoding='utf-8') as json_file:
        text_file = json.load(json_file)
        df_text = pd.DataFrame(text_file)
        texts_as_dfs.append(df_text)

# %%
lst_khm_ids
# Out:
# [103, 10, 11, 142, 171, 188, 18, 24, 28, 30, 36, 41, 42, 49, 56, 6, 80, 88, 89]

# %%
texts_as_dfs[0].head(10)
# Out:
#       tokens animate_tags     lemmas pos_tags dep_tags ner_tags  start_chars  \
# 0        Der    inanimate        der      DET      det        O            0
# 1       süße    inanimate        süß      ADJ     amod        O            4
# 2       Brei    inanimate       Brei     NOUN     root        O            9
# 3     Brüder    inanimate     Bruder     NOUN     root        O           21
# 4      Grimm    inanimate      Grimm    PROPN    appos    S-PER           28
# 5  Dieterich    inanimate  Dieterich    PROPN     root    S-PER           39
# 6          ,    inanimate          ,    PUNCT    punct        O           48
# 7  Göttingen    inanimate  Göttingen    PROPN     conj    S-LOC           50
# 8          ,    inanimate          ,    PUNCT    punct        O           59
# 9       1857    inanimate       1857      NUM     nmod        O           61
#
#    end_chars
# 0          3
# 1          8
# 2         13
# 3         27
# 4         33
# 5         48
# 6         49
# 7         59
# 8         60
# 9         65

# %%
ner_pers_tags = ['B-PER','I-PER','O-PER','E-PER','S-PER']

# %%
# Get share of person entities and animated entities per folktale

df_entity_counts = pd.DataFrame(columns=['khm_id','abs_freq_pers','rel_freq_pers','abs_freq_animate','rel_freq_animate'])

for i in range(0,len(texts_as_dfs)):
    df_entity_counts.at[i,'khm_id'] = lst_khm_ids[i]

    df = texts_as_dfs[i]

    ner_counts = df['ner_tags'].value_counts()

    ner_abs = 0
    for tag in ner_pers_tags:
        if tag in ner_counts:
            ner_abs+=ner_counts[tag]
    ner_rel = ner_abs/len(df)

    df_entity_counts.at[i,'abs_freq_pers'] = ner_abs
    df_entity_counts.at[i,'rel_freq_pers'] = ner_rel

    animate_abs = df['animate_tags'].value_counts()['animate']
    animate_rel = animate_abs/len(df)

    df_entity_counts.at[i,'abs_freq_animate'] = animate_abs
    df_entity_counts.at[i,'rel_freq_animate'] = animate_rel

# %%
df_entity_counts
# Out:
#    khm_id abs_freq_pers rel_freq_pers abs_freq_animate rel_freq_animate
# 0     103             2       0.00409               49         0.100204
# 1      10             6       0.00553              144         0.132719
# 2      11             8      0.002745              570         0.195607
# 3     142             6      0.005396              208          0.18705
# 4     171            11      0.007309              224         0.148837
# 5     188             4      0.002884              196         0.141312
# 6      18             4      0.005019               97         0.121706
# 7      24            18      0.011842              236         0.155263
# 8      28             4      0.003895              203         0.197663
# 9      30            17      0.024638              129         0.186957
# 10     36            71       0.01555              821         0.179807
# 11     41            11      0.017323              116         0.182677
# 12     42             7      0.007684              139          0.15258
# 13     49             6      0.002521              476              0.2
# 14     56            25      0.013528              347         0.187771
# 15      6            48      0.013227              632         0.174153
# 16     80             4      0.004233              153         0.161905
# 17     88             5      0.001783              536         0.191155
# 18     89            22      0.008658              505         0.198741

# %%
for index, row in df_entity_counts.iterrows():
    diff = row['rel_freq_pers']-row['rel_freq_animate']
    df_entity_counts.at[index,'difference'] = diff

# %%
df_entity_counts
# Out:
#    khm_id abs_freq_pers rel_freq_pers abs_freq_animate rel_freq_animate  \
# 0     103             2       0.00409               49         0.100204
# 1      10             6       0.00553              144         0.132719
# 2      11             8      0.002745              570         0.195607
# 3     142             6      0.005396              208          0.18705
# 4     171            11      0.007309              224         0.148837
# 5     188             4      0.002884              196         0.141312
# 6      18             4      0.005019               97         0.121706
# 7      24            18      0.011842              236         0.155263
# 8      28             4      0.003895              203         0.197663
# 9      30            17      0.024638              129         0.186957
# 10     36            71       0.01555              821         0.179807
# 11     41            11      0.017323              116         0.182677
# 12     42             7      0.007684              139          0.15258
# 13     49             6      0.002521              476              0.2
# 14     56            25      0.013528              347         0.187771
# 15      6            48      0.013227              632         0.174153
# 16     80             4      0.004233              153         0.161905
# 17     88             5      0.001783              536         0.191155
# 18     89            22      0.008658              505         0.198741
#
#     difference
# 0    -0.096115
# 1    -0.127189
# 2    -0.192862
# 3    -0.181655
# 4    -0.141528
# 5    -0.138428
# 6    -0.116688
# 7    -0.143421
# 8    -0.193768
# 9    -0.162319
# 10   -0.164258
# 11   -0.165354
# 12   -0.144896
# 13   -0.197479
# 14   -0.174242
# 15   -0.160926
# 16   -0.157672
# 17   -0.189372
# 18   -0.190083

# %%
df_entity_counts.sort_values('difference')
# Out:
#    khm_id abs_freq_pers rel_freq_pers abs_freq_animate rel_freq_animate  \
# 13     49             6      0.002521              476              0.2
# 8      28             4      0.003895              203         0.197663
# 2      11             8      0.002745              570         0.195607
# 18     89            22      0.008658              505         0.198741
# 17     88             5      0.001783              536         0.191155
# 3     142             6      0.005396              208          0.18705
# 14     56            25      0.013528              347         0.187771
# 11     41            11      0.017323              116         0.182677
# 10     36            71       0.01555              821         0.179807
# 9      30            17      0.024638              129         0.186957
# 15      6            48      0.013227              632         0.174153
# 16     80             4      0.004233              153         0.161905
# 12     42             7      0.007684              139          0.15258
# 7      24            18      0.011842              236         0.155263
# 4     171            11      0.007309              224         0.148837
# 5     188             4      0.002884              196         0.141312
# 1      10             6       0.00553              144         0.132719
# 6      18             4      0.005019               97         0.121706
# 0     103             2       0.00409               49         0.100204
#
#     difference
# 13   -0.197479
# 8    -0.193768
# 2    -0.192862
# 18   -0.190083
# 17   -0.189372
# 3    -0.181655
# 14   -0.174242
# 11   -0.165354
# 10   -0.164258
# 9    -0.162319
# 15   -0.160926
# 16   -0.157672
# 12   -0.144896
# 7    -0.143421
# 4    -0.141528
# 5    -0.138428
# 1    -0.127189
# 6    -0.116688
# 0    -0.096115

# %%
mean = df_entity_counts['difference'].mean()
mean
# Out:
# -0.15990811764411736

# %%
# Save df

df_entity_counts.to_csv('../Data/csv/df_frequency_counts_person_animate_entities.csv')

# %%
# Get entities that either person or animate entity or both

df_entity_tokens = pd.DataFrame(columns=['khm_id','left_context','token','right_context','pers_tag','animate_tag'])

j=0

for i in range(0,len(texts_as_dfs)):
    
    khm_id = df_entity_counts.at[i,'khm_id']

    df = texts_as_dfs[i]

    for index,row in df.iterrows():
        if row['ner_tags'].endswith('PER') or row['animate_tags'] == 'animate':
            df_entity_tokens.at[j,'khm_id'] = khm_id
            df_entity_tokens.at[j,'token'] = row['tokens']
            df_entity_tokens.at[j,'pers_tag'] = row['ner_tags']
            df_entity_tokens.at[j,'animate_tag'] = row['animate_tags']

            left_context = []
            right_context = []

            for k in list(range(int(index)-5,int(index))):
                if k < 0:
                    left_context.append('None')
                else:
                    left_context.append(df.iloc[k]['tokens'])

            df_entity_tokens.at[j,'left_context'] = left_context

            for k in list(range(int(index)+1,int(index)+6)):
                if k < len(df):
                    right_context.append(df.iloc[k]['tokens'])
                else:
                    right_context.append('None')

            df_entity_tokens.at[j,'right_context'] = right_context

            j+=1

# %%
df_entity_tokens.head()
# Out:
#   khm_id                      left_context      token  \
# 0    103   [None, Der, süße, Brei, Brüder]      Grimm
# 1    103  [Der, süße, Brei, Brüder, Grimm]  Dieterich
# 2    103        [Brei, ., Es, war, einmal]        ein
# 3    103         [., Es, war, einmal, ein]      armes
# 4    103     [Es, war, einmal, ein, armes]    frommes
#
#                          right_context pers_tag animate_tag
# 0   [Dieterich, ,, Göttingen, ,, 1857]    S-PER   inanimate
# 1  [,, Göttingen, ,, 1857, Exportiert]    S-PER   inanimate
# 2    [armes, frommes, Mädchen, ,, das]        O     animate
# 3    [frommes, Mädchen, ,, das, lebte]        O     animate
# 4        [Mädchen, ,, das, lebte, mit]        O     animate

# %%
df_entity_tokens.head(50)
# Out:
#    khm_id                            left_context      token  \
# 0     103         [None, Der, süße, Brei, Brüder]      Grimm
# 1     103        [Der, süße, Brei, Brüder, Grimm]  Dieterich
# 2     103              [Brei, ., Es, war, einmal]        ein
# 3     103               [., Es, war, einmal, ein]      armes
# 4     103           [Es, war, einmal, ein, armes]    frommes
# 5     103      [war, einmal, ein, armes, frommes]    Mädchen
# 6     103       [ein, armes, frommes, Mädchen, ,]        das
# 7     103           [Mädchen, ,, das, lebte, mit]     seiner
# 8     103            [,, das, lebte, mit, seiner]     Mutter
# 9     103        [seiner, Mutter, allein, ,, und]        sie
# 10    103               [zu, essen, ., Da, gieng]        das
# 11    103              [essen, ., Da, gieng, das]       Kind
# 12    103            [,, und, begegnete, ihm, da]       eine
# 13    103         [und, begegnete, ihm, da, eine]       alte
# 14    103        [begegnete, ihm, da, eine, alte]       Frau
# 15    103               [da, eine, alte, Frau, ,]        die
# 16    103  [seinen, Jammer, schon, und, schenkte]        ihm
# 17    103     [Jammer, schon, und, schenkte, ihm]        ein
# 18    103        [schon, und, schenkte, ihm, ein]   Töpfchen
# 19    103           [Töpfchen, ,, zu, dem, sollt]         es
# 20    103              [dem, sollt, es, sagen, „]   Töpfchen
# 21    103               [koche, ,, “, so, kochte]         es
# 22    103       [süßen, Hirsenbrei, ,, und, wenn]         es
# 23    103               [und, wenn, es, sagte, „]   Töpfchen
# 24    103                 [steh, ,, “, so, hörte]         es
# 25    103            [wieder, auf, zu, kochen, .]        Das
# 26    103               [auf, zu, kochen, ., Das]    Mädchen
# 27    103      [Das, Mädchen, brachte, den, Topf]     seiner
# 28    103   [Mädchen, brachte, den, Topf, seiner]     Mutter
# 29    103              [heim, ,, und, nun, waren]        sie
# 30    103               [,, und, nun, waren, sie]      ihrer
# 31    103        [waren, sie, ihrer, Armuth, und]      ihres
# 32    103            [aßen, süßen, Brei, so, oft]        sie
# 33    103               [., Auf, eine, Zeit, war]        das
# 34    103             [Auf, eine, Zeit, war, das]    Mädchen
# 35    103   [Mädchen, ausgegangen, ,, da, sprach]        die
# 36    103       [ausgegangen, ,, da, sprach, die]     Mutter
# 37    103            [da, sprach, die, Mutter, „]   Töpfchen
# 38    103      [sprach, die, Mutter, „, Töpfchen]          ,
# 39    103                [koche, ,, “, da, kocht]         es
# 40    103                 [da, kocht, es, ,, und]        sie
# 41    103                  [es, ,, und, sie, ißt]       sich
# 42    103              [sich, satt, ;, nun, will]        sie
# 43    103                [;, nun, will, sie, daß]        das
# 44    103              [nun, will, sie, daß, das]   Töpfchen
# 45    103       [wieder, aufhören, soll, ,, aber]        sie
# 46    103           [Wort, nicht, ., Also, kocht]         es
# 47    103              [übrig, ist, ,, da, kommt]        das
# 48    103                [ist, ,, da, kommt, das]       Kind
# 49    103               [,, und, spricht, nur, „]   Töpfchen
#
#                              right_context pers_tag animate_tag
# 0       [Dieterich, ,, Göttingen, ,, 1857]    S-PER   inanimate
# 1      [,, Göttingen, ,, 1857, Exportiert]    S-PER   inanimate
# 2        [armes, frommes, Mädchen, ,, das]        O     animate
# 3        [frommes, Mädchen, ,, das, lebte]        O     animate
# 4            [Mädchen, ,, das, lebte, mit]        O     animate
# 5             [,, das, lebte, mit, seiner]        O     animate
# 6     [lebte, mit, seiner, Mutter, allein]        O     animate
# 7            [Mutter, allein, ,, und, sie]        O     animate
# 8            [allein, ,, und, sie, hatten]        O     animate
# 9        [hatten, nichts, mehr, zu, essen]        O     animate
# 10           [Kind, hinaus, in, den, Wald]        O     animate
# 11              [hinaus, in, den, Wald, ,]        O     animate
# 12             [alte, Frau, ,, die, wußte]        O     animate
# 13           [Frau, ,, die, wußte, seinen]        O     animate
# 14         [,, die, wußte, seinen, Jammer]        O     animate
# 15     [wußte, seinen, Jammer, schon, und]        O     animate
# 16             [ein, Töpfchen, ,, zu, dem]        O     animate
# 17           [Töpfchen, ,, zu, dem, sollt]        O     animate
# 18                 [,, zu, dem, sollt, es]        O     animate
# 19          [sagen, „, Töpfchen, ,, koche]        O     animate
# 20                    [,, koche, ,, “, so]        O     animate
# 21      [guten, süßen, Hirsenbrei, ,, und]        O     animate
# 22           [sagte, „, Töpfchen, ,, steh]        O     animate
# 23                     [,, steh, ,, “, so]        O     animate
# 24            [wieder, auf, zu, kochen, .]        O     animate
# 25   [Mädchen, brachte, den, Topf, seiner]        O     animate
# 26    [brachte, den, Topf, seiner, Mutter]        O     animate
# 27             [Mutter, heim, ,, und, nun]        O     animate
# 28              [heim, ,, und, nun, waren]        O     animate
# 29    [ihrer, Armuth, und, ihres, Hungers]        O     animate
# 30    [Armuth, und, ihres, Hungers, ledig]        O     animate
# 31      [Hungers, ledig, und, aßen, süßen]        O     animate
# 32           [wollten, ., Auf, eine, Zeit]        O     animate
# 33   [Mädchen, ausgegangen, ,, da, sprach]        O     animate
# 34       [ausgegangen, ,, da, sprach, die]        O     animate
# 35         [Mutter, „, Töpfchen, ,, koche]        O     animate
# 36              [„, Töpfchen, ,, koche, ,]        O     animate
# 37                    [,, koche, ,, “, da]        O     animate
# 38                [koche, ,, “, da, kocht]        O     animate
# 39                [,, und, sie, ißt, sich]        O     animate
# 40               [ißt, sich, satt, ;, nun]        O     animate
# 41               [satt, ;, nun, will, sie]        O     animate
# 42  [daß, das, Töpfchen, wieder, aufhören]        O     animate
# 43   [Töpfchen, wieder, aufhören, soll, ,]        O     animate
# 44       [wieder, aufhören, soll, ,, aber]        O     animate
# 45             [weiß, das, Wort, nicht, .]        O     animate
# 46               [fort, ,, und, der, Brei]        O     animate
# 47           [Kind, heim, ,, und, spricht]        O     animate
# 48            [heim, ,, und, spricht, nur]        O     animate
# 49                     [,, steh, ,, “, da]        O     animate

# %%
df_entity_tokens.tail()
# Out:
#      khm_id                             left_context     token  \
# 5882     89           [sich, der, junge, König, mit]    seiner
# 5883     89         [der, junge, König, mit, seiner]   rechten
# 5884     89     [junge, König, mit, seiner, rechten]  Gemahlin
# 5885     89      [seiner, rechten, Gemahlin, ,, und]     beide
# 5886     89  [Gemahlin, ,, und, beide, beherrschten]       ihr
#
#                                 right_context pers_tag animate_tag
# 5882       [rechten, Gemahlin, ,, und, beide]        O     animate
# 5883  [Gemahlin, ,, und, beide, beherrschten]        O     animate
# 5884       [,, und, beide, beherrschten, ihr]        O     animate
# 5885  [beherrschten, ihr, Reich, in, Frieden]        O     animate
# 5886     [Reich, in, Frieden, und, Seligkeit]        O     animate

# %%
# Save df

df_entity_tokens.to_csv('../Data/csv/df_person_animate_tokens_all.csv', encoding='utf-8-sig', sep ='\t')

# %%
ner_pers_tags
# Out:
# ['B-PER', 'I-PER', 'O-PER', 'E-PER', 'S-PER']

# %%
# Measure overlap

i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in ner_pers_tags and animate_tag=='animate':
        i+=1

print('person entity and animate entity: ',i)
# Out:
# person entity and animate entity:  173

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in ner_pers_tags and animate_tag=='inanimate':
        i+=1

print('person entity and inanimate entity: ',i)
# Out:
# person entity and inanimate entity:  106

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag not in ner_pers_tags and animate_tag=='animate':
        i+=1

print('other entity/no entity and animate entity: ',i)
# Out:
# other entity/no entity and animate entity:  5608

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag not in ner_pers_tags and animate_tag=='inanimate':
        i+=1

print('other entity/no entity and inanimate entity: ',i)
# Out:
# other entity/no entity and inanimate entity:  0

# %%
lst_entities = df_entity_tokens['pers_tag'].to_list()

# %%
set(lst_entities)
# Out:
# {'B-LOC', 'B-PER', 'E-LOC', 'E-PER', 'O', 'S-LOC', 'S-PER'}

# %%
ner_other_tags = ['B-LOC', 'E-LOC', 'S-LOC']

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in ner_other_tags and animate_tag=='animate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  20

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in ner_other_tags and animate_tag=='inanimate':
        i+=1

print('other entity and inanimate entity: ',i)
# Out:
# other entity and inanimate entity:  0

# %%
lst_ner_all = ner_pers_tags.copy()
lst_ner_all.extend(ner_other_tags)
lst_ner_all
# Out:
# ['B-PER', 'I-PER', 'O-PER', 'E-PER', 'S-PER', 'B-LOC', 'E-LOC', 'S-LOC']

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in lst_ner_all and animate_tag=='animate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  193

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag in lst_ner_all and animate_tag=='inanimate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  106

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag not in lst_ner_all and animate_tag=='animate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  5588

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag == 'O' and animate_tag=='animate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  5588

# %%
i = 0

for indes, row in df_entity_tokens.iterrows():
    pers_tag = row['pers_tag']
    animate_tag = row['animate_tag']

    if pers_tag not in lst_ner_all and animate_tag=='inanimate':
        i+=1

print('other entity and animate entity: ',i)
# Out:
# other entity and animate entity:  0

# %% [markdown]
# ### POS

# %%
## Load data, linguistic features and labels

# Read text data from files
input_folder = '../Data/annotations'

# %%
texts_khm_id = []
texts_tokens = []
texts_lemmas = []
texts_pos_tags = []
texts_dep_tags = []
texts_ner_tags = []
texts_animate_labels = []

# %%
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    with open(file_path, 'r', encoding='utf-8') as json_file:
        text_file = json.load(json_file)
        df_text = pd.DataFrame(text_file)
        texts_khm_id.append(filename.replace('_annotations.json', ''))
        texts_tokens.append(df_text['tokens'].to_list())
        texts_lemmas.append(df_text['lemmas'].to_list())
        texts_pos_tags.append(df_text['pos_tags'].to_list())
        texts_dep_tags.append(df_text['dep_tags'].to_list())
        texts_ner_tags.append(df_text['ner_tags'].to_list())
        texts_animate_labels.append(df_text['animate_tags'].to_list())

# %%
i = 0
for text in texts_tokens:
    for token in text:
        i+=1
print(i)

# %%
i = 0
for text in texts_pos_tags:
    for pos in text:
        i+=1
print(i)

# %%
df = pd.DataFrame(columns=['token','pos_tag','animate_label'])

# %%
tokens = [token for text in texts_tokens for token in text]

# %%
len(tokens)

# %%
pos_tags = [pos_tag for text in texts_pos_tags for pos_tag in text]

# %%
animate_labels = [label for text in texts_animate_labels for label in text]

# %%
count_animate = animate_labels.count('animate')
count_animate

# %%
count_inanimate = animate_labels.count('inanimate')
count_inanimate

# %%
df['token']=tokens
df['pos_tag']=pos_tags
df['animate_label']=animate_labels

# %%
len(df)

# %%
df.head()

# %%
df.head(20)

# %%
set(df['pos_tag'].to_list())

# %%
noun_tags = ['NOUN','PROPN']

# %%
i = 0

for index,row in df.iterrows():
    if row['pos_tag'] in noun_tags and row['animate_label']=='animate':
        i+=1

print('absolute frequency: ',i,', percentage: ',i/count_animate*100)

# %%
i = 0

for index,row in df.iterrows():
    if row['pos_tag'] in noun_tags and row['animate_label']=='animate':
        i+=1

print('absolute frequency: ',i,', percentage: ',i/count_inanimate*100)

# %%
# Excluding punctuation

i=0

for index,row in df.iterrows():
    if row['pos_tag'] == 'X':
        print(row['token'])
        i+=1
i

# %%
freq_punct = 0

for index,row in df.iterrows():
    if row['pos_tag'] == 'PUNCT':
        freq_punct+=1
freq_punct

# %%
freq_punct/len(df)*100
